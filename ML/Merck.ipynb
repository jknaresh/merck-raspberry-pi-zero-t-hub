# %%
import pandas as pd
import numpy as np
data=pd.read_csv('rberry_temphumidity.csv')
#data

# %%
import datetime
data['c_1']=pd.to_datetime(data['c_on'])
#
data['c_h']=data['c_1'].dt.hour

# %%
data.plot(kind='scatter',x='c_h',y='temp')

# %%
import seaborn as sns
data.head()
sns.boxplot(x="c_h", y='humidity',data=data)
